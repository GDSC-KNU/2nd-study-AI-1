# %%
import cv2
import matplotlib.pyplot as plt
# Out:
# Running cells with 'c:\Users\user\AppData\Local\Programs\Python\Python311\python.exe' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/user/AppData/Local/Programs/Python/Python311/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
# Process an image and save it to another file.
# !python yolact/eval.py --trained_model=yolact/weights/yolact_base_54_800000.pth --score_threshold=0.15 --top_k=15 --image=Data/image/face01.jpg:Data/image/face01_yolact_result.jpg
# !python yolact/eval.py --trained_model=yolact/weights/yolact_base_54_800000.pth --score_threshold=0.15 --top_k=15 --image=Data/image/face02.jpg:Data/image/face02_yolact_result.jpg
# Out:
# Config not specified. Parsed yolact_base_config from the file name.
#
# Loading model... Done.
# D:\anaconda\lib\site-packages\torch\jit\_recursive.py:256: UserWarning: 'downsample_layers' was found in ScriptModule constants,  but it is a non-constant submodule. Consider removing it.
#   warnings.warn("'{}' was found in ScriptModule constants, "
# D:\anaconda\lib\site-packages\torch\jit\_recursive.py:256: UserWarning: 'lat_layers' was found in ScriptModule constants,  but it is a non-constant submodule. Consider removing it.
#   warnings.warn("'{}' was found in ScriptModule constants, "
# D:\anaconda\lib\site-packages\torch\jit\_recursive.py:256: UserWarning: 'pred_layers' was found in ScriptModule constants,  but it is a non-constant submodule. Consider removing it.
#   warnings.warn("'{}' was found in ScriptModule constants, "
# Config not specified. Parsed yolact_base_config from the file name.
#
# Loading model... Done.
# ...

# %%
img = cv2.imread('Data/image/face01_yolact_result.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.title('Detected Image')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
img = cv2.imread('Data/image/face02_yolact_result.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.title('Detected Image')
plt.xticks([]), plt.yticks([])
plt.show()
